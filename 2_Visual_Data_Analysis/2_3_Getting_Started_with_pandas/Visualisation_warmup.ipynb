# %% [markdown]
# # Warmup challenge!

# %% [markdown]
# ![](polynomial.png)

# %% [markdown]
# ## Warmup challenge! See if you can reproduce the above polynomial plot.
# * We can do everything with lists, and the below syntax to make a new plot

# %%
import matplotlib.pyplot as plt
x= range(5)
y= range(0,10,2)
if len(x) == len(y):
    print('Data has the right shape!')
    plt.plot(x,y)
else:
    print('Sorry, data is mismatched')
# Out:
# Data has the right shape!
